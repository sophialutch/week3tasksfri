# %% [markdown]
# # Getting Data from Wikipedia
#
# This notebook shows initially how to work with the **mwclient** library to exlore the content of Wikipedia pages. It's an example of a API wrapper, that facilitates working with the underlying API, the [MediaWikiAPI](https://www.mediawiki.org/wiki/API:Main_page).
#
# Then, we introduce a similar wrapper library, **mwviews**, to get the page views for an article. We then combine data that we can get from these two libraries, so that you can explore the concept of "anticipated hits" vs. "sleeper hits"
#
# **Table of Content**
# 1. [Installing the `mwclient` module](#sec1)
# 2. [Connecting to a site and working with pages](#sec2)
# 3. [The Wellesley College page](#sec3)
# 4. [Exploring Wellesley's Wiki page revisions](#sec4)
# 5. [Accessing Pageviews for Wiki pages](#sec5)

# %% [markdown]
# ## 1. Installing the `mwclient` module
#
# In this notebook I've used the module [mwclient](http://mwclient.readthedocs.io/en/latest/index.html). The name stands for "Media Wiki Client". It's a library to access the Wikipedia pages through Python.
#
# Since this is your first time using this library, you have to install it first.

# %%
pip install mwclient
# Out:
# Collecting mwclient
#   Downloading mwclient-0.11.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting requests-oauthlib (from mwclient)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->mwclient)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests-oauthlib->mwclient) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2026.7.22)
# Downloading mwclient-0.11.0-py3-none-any.whl (33 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: oauthlib, requests-oauthlib, mwclient
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [mwclient]
# Successfully installed mwclient-0.11.0 oauthlib-3.3.1 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# check if module is installed
import mwclient

# %% [markdown]
# <a id="sec2"></a>

# %% [markdown]
# ## 2. Connecting to a wiki site and getting pages
#
# There are many wiki websites that are accessed by MediaWikiAPI. We need to provide the URL of the one we will work with, in our case the English Wikipedia.

# %%
from mwclient import Site
site = Site('en.wikipedia.org')

# %% [markdown]
# It's possible to search for pages based on a simple query term, given that we will search within the `site`:

# %%
page = site.pages['Wellesley']
page
# Out:
# <Page object 'Wellesley' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# And we can read the text of the page, which in this case appears to be a disambiguation page with links to many pages that contain the word "Wellesley":

# %%
page.text()
# Out:
# "'''Wellesley''' may refer to:\n{{TOC right}}\n\n== People ==\n===Dukes of Wellington===\n* [[Arthur Wellesley, 1st Duke of Wellington]] (1769–1852), British soldier, statesman, and Prime Minister of the United Kingdom\n* [[Arthur Wellesley, 2nd Duke of Wellington]] (1807–1884), British politician\n* [[Henry Wellesley, 3rd Duke of Wellington]] (1846–1900), British soldier and politician\n* [[Arthur Wellesley, 4th Duke of Wellington]] (1849–1934), British soldier\n* [[Arthur Wellesley, 5th Duke of Wellington]] (1876–1941), British soldier\n* [[Henry Wellesley, 6th Duke of Wellington]] (1912–1943), British soldier\n* [[Gerald Wellesley, 7th Duke of Wellington]] (1885–1972), British soldier and diplomat\n* [[Valerian Wellesley, 8th Duke of Wellington]] (1915–2014), British soldier\n* [[Charles Wellesley, 9th Duke of Wellington]] (born 1945), British politician and a businessman\n\n=== Barons Cowley (1828) ===\n* [[Henry Wellesley, 1st Baron Cowley]] (1773–1847)\n* [[Henry Wellesley, 1st Earl Cowley|Henry Richard Charles Wellesley, 2nd Baron Cowley]] (1804–1884) (created '''Earl Cowley''' in 1857)\n\n=== Earls Cowley (1857) ===\n* [[Henry Wellesley, 1st Earl Cowley|Henry Richard Charles Wellesley, 1st Earl Cowley]] (1804–1884)\n* [[William Wellesley, 2nd Earl Cowley|William Henry Wellesley, 2nd Earl Cowley]] (1834–1895)\n* [[Henry Arthur Mornington Wellesley, 3rd Earl Cowley]] (1866–1919)\n* [[Christian Arthur Wellesley, 4th Earl Cowley]] (1890–1962)\n* [[Denis Wellesley, 5th Earl Cowley|Denis Arthur Wellesley, 5th Earl Cowley]] (1921–1968)\n* [[Richard Wellesley, 6th Earl Cowley|Richard Francis Wellesley, 6th Earl Cowley]] (1946–1975)\n* [[Garret Wellesley, 7th Earl Cowley|Garret Graham Wellesley, 7th Earl Cowley]] (1934–2016)\n* Garret [[Graham Wellesley, 8th Earl Cowley]] (born 30 March 1965), styled Viscount Dangan from 1975 to 2016\n\nThe [[heir apparent]] is the present holder's son Henry Arthur Peter Wellesley, Viscount Dangan (b. 1991).\n\n===Others, including relatives of Dukes===\n* [[Arthur Wellesley, Marquess of Douro]] (born 1978), British businessman\n* [[Lord Charles Wellesley]] (1808–1858), British politician\n* [[Charles Wellesley]] (1873–1946), American actor\n* [[Lady Charlotte Wellesley]] (born 1990), British producer and socialite\n* [[Elizabeth Wellesley, Duchess of Wellington]] (1820–1904), Mistress of the Robes\n* [[Lady Elizabeth Wellesley]] (1918–2013), British socialite\n* [[Lord George Wellesley]] (1889–1967), British soldier\n* [[Gerald Valerian Wellesley (born 1770)|Gerald Valerian Wellesley]] (1770–1848), Irish clergyman\n* [[Lady Jane Wellesley]] (born 1951), British writer and television producer\n* [[Richard Wellesley, 1st Marquess Wellesley]] (1760–1842), Irish peer, statesman, and Governor-General of India\n* [[Walter Wellesley]] (c. 1470–1539), prior of Great Connell priory and bishop of Kildare\n* [[Wellesley Wilson Staples]], Canadian politician from Ontario\n\n== Places and institutions ==\n\n=== Australia ===\n\n* [[Wellesley, Queensland]], a locality in the Maranoa Region\n* [[Wellesley Islands]], an island group in the Gulf of Carpentaria, Queensland, and locality in the Shire of Mornington\n**[[South Wellesley Islands]], an island group in the Gulf of Carpentaria, Queensland, and locality in the Shire of Mornington\n**[[West Wellesley Islands]], an island group in the Gulf of Carpentaria, Queensland, and locality in the Shire of Mornington\n* [[Wellesley, Western Australia]], a locality in the Shire of Harvey\n\n=== Canada ===\n\n* [[Wellesley, Ontario]], Canada, a township\n* [[Wellesley (TTC)]], a subway station in Toronto, Ontario\n\n=== Malaysia ===\n\n* [[Province Wellesley]], Penang, Malaysia, known in Malay as Seberang Prai\n\n=== New Zealand ===\n\n* [[Wellesley College, New Zealand]], private boys-only independent primary school in New Zealand\n\n=== United States ===\n\n*[[Wellesley, Massachusetts]], United States\n**[[Wellesley College]], private women's liberal arts college i ...

# %% [markdown]
# ### 2.a What else does a page contain?
#
# Let's looks at some properties that the page contains:

# %% [markdown]
# **Categories:** Most pages in Wikipedia are assigned categories, which we can access:

# %%
for cat in page.categories():
    print(cat)
# Out:
# <Category object 'Category:All article disambiguation pages' for <Site object 'en.wikipedia.org/w/'>>
# <Category object 'Category:All disambiguation pages' for <Site object 'en.wikipedia.org/w/'>>
# <Category object 'Category:Disambiguation pages' for <Site object 'en.wikipedia.org/w/'>>
# <Category object 'Category:Disambiguation pages with surname-holder lists' for <Site object 'en.wikipedia.org/w/'>>
# <Category object 'Category:Place name disambiguation pages' for <Site object 'en.wikipedia.org/w/'>>
# <Category object 'Category:Short description is different from Wikidata' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# **Links:** A page has many links to other Wikipedia pages, we can access them too:

# %%
links = [l for l in page.links()]
print(f"Total links: {len(links)}")
# Out:
# Total links: 48

# %%
links[:5]
# Out:
# [<Page object 'Denis Wellesley, 5th Earl Cowley' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Arthur Wellesley, 1st Duke of Wellington' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Arthur Wellesley, 2nd Duke of Wellington' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Arthur Wellesley, 4th Duke of Wellington' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Arthur Wellesley, 5th Duke of Wellington' for <Site object 'en.wikipedia.org/w/'>>]

# %% [markdown]
# **IMPORTANT - Lazy behavior:** Simply calling the method `links` on the page object will not give us the list of links:

# %%
page.links()
# Out:
# <PagePropertyGenerator object 'links' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# We need to iterate over this object to get the links, which themselves are objects pointing to the pages.

# %% [markdown]
# ### 2.b What's in a page object?
#
# As we saw above, each link shows up as a page object in the list of links. This is because these are all Wikipedia articles. Let's verify again that each page is an object:

# %%
type(page)
# Out:
# mwclient.page.Page

# %% [markdown]
# We can use the Python built-in function `dir` to find out what properties or methods we can call on this object:

# %%
onePage = links[10]
dir(onePage)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_edit',
#  '_info',
#  '_textcache',
#  'append',
#  'backlinks',
#  'base_name',
#  'base_title',
#  'can',
#  'categories',
#  'contentmodel',
#  'delete',
#  'edit',
#  'edit_time',
#  'embeddedin',
#  'exists',
#  'extlinks',
#  'get_token',
#  'handle_edit_error',
#  'images',
#  'iwlinks',
#  'langlinks',
#  'last_rev_time',
#  'length',
#  'links',
#  'move',
#  'name',
#  'namespace',
#  'normalize_title',
#  'page_title',
#  'pageid',
#  'pagelanguage',
#  'prepend',
#  'protection',
#  'purge',
#  'redirect',
#  'redirects_to',
#  'resolve_redirect',
#  'restrictiontypes',
#  'revision',
#  'revisions',
#  'save',
#  'site',
#  'strip_namespace',
#  'templates',
#  'text',
#  'touch',
#  'touched']

# %% [markdown]
# Let's try out some of the properties:

# %%
# length of page in characters
onePage.length
# Out:
# 5329

# %%
# name of the page
onePage.name
# Out:
# 'Elizabeth Wellesley, Duchess of Wellington'

# %%
# timestamp of when the page was "touched" or modified (not necessarily edited by users)
onePage.touched
# Out:
# time.struct_time(tm_year=2026, tm_mon=9, tm_mday=16, tm_hour=10, tm_min=53, tm_sec=28, tm_wday=2, tm_yday=259, tm_isdst=-1)

# %% [markdown]
# **Note:** Notice the type `time.struct_time` that is used to represent time in Wikipedia. (There is a separate tutorial that explains this type.)

# %% [markdown]
# <a id="sec3"></a>

# %% [markdown]
# ## 3. The Wellesley College page
#
# Let's get the Wellesley College page and look at its properties. Instead of searching for "Wellesley", let's search for "Wellesley College":

# %%
wcp = site.pages['Wellesley College']
wcp.name
# Out:
# 'Wellesley College'

# %% [markdown]
# Is it a protected page? Meaning, can anyone edit it, or are there some restrictions in place? In Wikipedia, some pages are protected to prevent vandalism.

# %%
wcp.protection
# Out:
# {}

# %% [markdown]
# No, it's not. But, we can easily find a page that is protected:

# %%
hcp = site.pages['Hillary Clinton']
hcp.name
# Out:
# 'Hillary Clinton'

# %%
hcp.protection
# Out:
# {'edit': ('autoconfirmed', 'infinity'), 'move': ('sysop', 'infinity')}

# %% [markdown]
# Notice that the result this time looks different from that of the Wellesley page. For example, only **autoconfirmed** users can edit the page. **autoconfirmed** means user accounts that have made at least 10 edits to the English Wikipedia and after 4 days have passed since the time of their first edit. You can learn more about levels of user access on Wikipedia [in this page](https://en.wikipedia.org/wiki/Wikipedia:User_access_levels).

# %% [markdown]
# What is the length of the page in characters?

# %%
wcp.length # length of page in characters
# Out:
# 76374

# %% [markdown]
# Get external links from this page (links that go outside Wikipedia):

# %%
extlinks = [el for el in wcp.extlinks()]
len(extlinks)
# Out:
# 208

# %%
extlinks[:10]
# Out:
# ['http://www.wellesley.edu/sfs/UnderstandingFinAid.html',
#  'http://www.wellesley.edu/PublicAffairs/Releases/2009/042509.html',
#  'http://www.wellesley.edu/Welcome/Traditions/hooprolling.html',
#  'http://www.wellesley.edu/Welcome/HistoricalMaps/maps_main.html',
#  'http://new.wellesley.edu/admission/esp/nontraditional',
#  'http://www.wellesley.edu/PublicAffairs/About/briefhistory.html',
#  'http://www.travelandleisure.com/articles/americas-most-beautiful-college-campuses/23',
#  'http://www.virtualvermont.com/history/hgreen.html',
#  'http://www.wellesley.edu/advising/classdeans/engineering/dd',
#  'http://www.wellesley.edu/advising/classdeans/engineering/dual-degree-with-olin']

# %% [markdown]
# Find all Wikipedia pages that link to Wellesley College, these are known as **backlinks**:

# %%
backlinks = [el for el in wcp.backlinks()]
len(backlinks)
# Out:
# 2945

# %% [markdown]
# That is a lot of backlinks that point to the Wellesley College page from other Wikipedia pages!

# %%
backlinks[:10]
# Out:
# [<Page object 'America the Beautiful' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Basketball' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Brown University' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Barnard College' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'College' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'California Institute of Technology' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Columbia University' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Colonna family' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'City University of New York' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Dartmouth College' for <Site object 'en.wikipedia.org/w/'>>]

# %% [markdown]
# Finally, look at the links from this page to other Wikipedia pages:

# %%
links = [el for el in wcp.links()]
len(links)
# Out:
# 584

# %%
links[:10]
# Out:
# [<Page object 'Judy Atterbury' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'ACT (test)' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Ada Howard' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Adaline Emerson Thompson' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Adrian Piper' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Agnes Scott College' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Alan Schechter' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Albion College' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Albright College' for <Site object 'en.wikipedia.org/w/'>>,
#  <Page object 'Ali MacGraw' for <Site object 'en.wikipedia.org/w/'>>]

# %% [markdown]
# We can say that more pages link to Wellesley College than vice-versa.
#
# **IMPORTANT:** The links to other pages are useful to find things that are related. Even better are reciprocal links: pages that point to each-other.

# %% [markdown]
# <a id="sec4"></a>
# ## 4. Exploring the Wellesley page revisions
#
# We can see that the object `page` has two properties, `revision` and `revisions`, let's look at them:

# %%
wcp.revision
# Out:
# 1368434600

# %%
wcp.revisions
# Out:
# <bound method Page.revisions of <Page object 'Wellesley College' for <Site object 'en.wikipedia.org/w/'>>>

# %% [markdown]
# The message shows that `revisions` is a method, not a property, we'll need parens to access it:

# %%
wcp.revisions()
# Out:
# <RevisionsIterator object 'revisions' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# We can see the pattern now, most functions return **lazy objects**, because the user might not be interested in everything.
#
# **Get all revisions:** We can get all revisions we want by looping through the list iterator. This might take a few seconds.

# %%
revisions = [rev for rev in wcp.revisions()]
len(revisions)
# Out:
# 2454

# %%
revisions[:3]
# Out:
# [OrderedDict([('revid', 1368434600),
#               ('parentid', 1363872253),
#               ('user', 'Jevansen'),
#               ('timestamp',
#                time.struct_time(tm_year=2026, tm_mon=8, tm_mday=9, tm_hour=1, tm_min=7, tm_sec=23, tm_wday=6, tm_yday=221, tm_isdst=-1)),
#               ('comment',
#                'Copying from [[Category:Universities and colleges established in 1875]] to [[Category:Educational institutions in the United States established in 1875]] using [[c:Help:Cat-a-lot|Cat-a-lot]]')]),
#  OrderedDict([('revid', 1363872253),
#               ('parentid', 1359916075),
#               ('user', 'Kamenûk'),
#               ('timestamp',
#                time.struct_time(tm_year=2026, tm_mon=7, tm_mday=13, tm_hour=0, tm_min=46, tm_sec=50, tm_wday=0, tm_yday=194, tm_isdst=-1)),
#               ('comment', 'Spacing, and a link')]),
#  OrderedDict([('revid', 1359916075),
#               ('parentid', 1358043588),
#               ('minor', ''),
#               ('user', 'Zackmann08'),
#               ('timestamp',
#                time.struct_time(tm_year=2026, tm_mon=6, tm_mday=18, tm_hour=1, tm_min=30, tm_sec=6, tm_wday=3, tm_yday=169, tm_isdst=-1)),
#               ('comment',
#                'fixing infobox and removing [[Category:Pages using infobox university with deprecated parameters|deprecated parameters]]; Cleaning up syntax using [[:en:User:Zackmann08/scripts/indent|indent.js]]')])]

# %% [markdown]
# ### 4.a Find users in revisions
#
# Each revision is stored as a Python dictionary, so we can easily extract the users:

# %%
users = [rev['user'] for rev in revisions]

# %% [markdown]
# We'll use `Counter` to create a dict of users with their counts and then print these users based on the number of edits, with the most common edits at the top:

# %%
from collections import Counter

usersDct = Counter(users)
usersDct.most_common(10)
# Out:
# [('Contributor321', 66),
#  ('ElKevbo', 64),
#  ('Interestingstuffadder', 46),
#  ('Jay-Wiki', 41),
#  ('173.77.203.132', 35),
#  ('Classicfilms', 27),
#  ('Catamorphism', 25),
#  ('Cellmesellme', 20),
#  ('Rjensen', 19),
#  ('RegentsPark', 18)]

# %% [markdown]
# **Note:** When I taught CS 234 in 2017, CS 234 students edited the Wellesley College page on Wikipedia.
#
# Let's check the count of edits for some of CS 234 editors of the page:

# %%
usersDct['Imanh19']
# Out:
# 3

# %%
usersDct['Angelinahli']
# Out:
# 6

# %% [markdown]
# How many unique users have edited this page?

# %%
print(f"{len(usersDct)} unique users have edited {len(revisions)} times the {wcp.name} Wikipedia page.")
# Out:
# 1247 unique users have edited 2454 times the Wellesley College Wikipedia page.

# %% [markdown]
# ### 4.b Working with timestamps
#
# Each revision contains a timestamp. Let's convert that to a datetime object to make it easier to work with it.
# **NOTE:** To make sense of this part, you need to have completed the notebook on working with date & time objects in Week 3 tasks.

# %%
ts = revisions[0]['timestamp']
ts
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=9, tm_hour=1, tm_min=7, tm_sec=23, tm_wday=6, tm_yday=221, tm_isdst=-1)

# %%
type(ts)
# Out:
# time.struct_time

# %% [markdown]
# The following modules will work together to make the conversion from `timestruct` to `datetime`:

# %%
from time import mktime
from datetime import datetime

# turn an object from type struct_time to datetime
datetime.fromtimestamp(mktime(ts))
# Out:
# datetime.datetime(2026, 8, 9, 1, 7, 23)

# %% [markdown]
# Now that we have a datetime object, we can do many things:
#
# 1. group number of revisions by day
# 2. group number of revisions by month or year
# 3. group revisions by user revisions per day

# %% [markdown]
# A reminder that a datetime object has properties to access values such as year and month:

# %%
dt = datetime.fromtimestamp(mktime(ts))
print(dt.year)
print(dt.month)
print(dt.day)
# Out:
# 2026
# 8
# 9

# %% [markdown]
# As well as a useful method to return only the date (without the time portion):

# %%
print(dt.date())
# Out:
# 2026-08-09

# %% [markdown]
# This is especially useful in the succeeding example.

# %% [markdown]
# **Example: What was the day with most revisions?**
#
# First, we convert all timestamps into string dates, just because it is easier to store them than datetime objects.

# %%
def createDateTime(timestamp):
    """convert a timestruct to datetime"""
    return datetime.fromtimestamp(mktime(timestamp))

dates = [str(createDateTime(rev['timestamp']).date()) for rev in revisions]

# what does str(createDateTime(rev['timestamp']).date()) do?
# 1. it call the function createDateTime with each revision's timestamp object
# 2. then it applies the method date() on the returned datetime object, to get a date object
# 3. it converts the date object into a string

dates[:10]
# Out:
# ['2026-08-09',
#  '2026-07-13',
#  '2026-06-18',
#  '2026-06-06',
#  '2026-06-06',
#  '2026-06-06',
#  '2026-06-06',
#  '2026-05-29',
#  '2026-05-29',
#  '2026-05-08']

# %% [markdown]
# **Find days with most edits**
#
# We can do this in the same way we found the users with most edits, using the `Counter` constructor:

# %%
datesDct = Counter(dates)
datesDct.most_common(10)
# Out:
# [('2024-05-09', 34),
#  ('2023-11-14', 19),
#  ('2008-07-10', 16),
#  ('2008-07-23', 14),
#  ('2006-08-09', 14),
#  ('2017-09-29', 13),
#  ('2010-06-29', 13),
#  ('2009-04-05', 13),
#  ('2020-06-24', 12),
#  ('2014-07-08', 12)]

# %% [markdown]
# <a id='sec5'></a>
# ## 5. Wikipedia Pageviews
#
# Similarly to the mwclient library we just saw, another library, mwviews, provides easy access to pageviews of every Wikipedia article.
#
# First let's install the library:

# %%
pip install mwviews
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=96162) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Collecting mwviews
#   Downloading mwviews-0.2.1-py3-none-any.whl.metadata (543 bytes)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mwviews) (2.34.2)
# Collecting more-itertools (from mwviews)
#   Downloading more_itertools-11.1.0-py3-none-any.whl.metadata (41 kB)
# Collecting docopt (from mwviews)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mwcli (from mwviews)
#   Downloading mwcli-0.0.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting mwapi (from mwviews)
#   Downloading mwapi-0.6.1-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting aiohttp (from mwapi->mwviews)
#   Downloading aiohttp-3.14.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->mwapi->mwviews)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->mwapi->mwviews)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp->mwapi->mwviews) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->mwapi->mwviews)
#   Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->mwapi->mwviews)
#   Downloading multidict-6.9.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->mwapi->mwviews)
#   Downloading propcache-0.5.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (25 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->mwapi->mwviews)
#   Downloading yarl-1.25.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (111 kB)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp->mwapi->mwviews) (3.19)
# Collecting para (from mwcli->mwviews)
#   Downloading para-0.0.8-py3-none-any.whl.metadata (2.0 kB)
# Collecting mwxml (from mwcli->mwviews)
#   Downloading mwxml-0.3.8-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting mwtypes>=0.4.0 (from mwxml->mwcli->mwviews)
#   Downloading mwtypes-0.4.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema>=2.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mwxml->mwcli->mwviews) (4.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (0.23.1)
# Collecting jsonable>=0.3.0 (from mwtypes>=0.4.0->mwxml->mwcli->mwviews)
#   Downloading jsonable-0.3.1-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->mwviews) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->mwviews) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests->mwviews) (2026.7.22)
# Downloading mwviews-0.2.1-py3-none-any.whl (9.8 kB)
# Downloading more_itertools-11.1.0-py3-none-any.whl (72 kB)
# Downloading mwapi-0.6.1-py2.py3-none-any.whl (12 kB)
# Downloading aiohttp-3.14.3-cp313-cp313-macosx_11_0_arm64.whl (509 kB)
# Downloading multidict-6.9.0-cp313-cp313-macosx_11_0_arm64.whl (54 kB)
# Downloading yarl-1.25.1-cp313-cp313-macosx_11_0_arm64.whl (103 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl (49 kB)
# Downloading propcache-0.5.4-cp313-cp313-macosx_11_0_arm64.whl (51 kB)
# Downloading mwcli-0.0.3-py2.py3-none-any.whl (8.4 kB)
# Downloading mwxml-0.3.8-py2.py3-none-any.whl (35 kB)
# Downloading mwtypes-0.4.0-py2.py3-none-any.whl (20 kB)
# Downloading jsonable-0.3.1-py2.py3-none-any.whl (11 kB)
# Downloading para-0.0.8-py3-none-any.whl (6.5 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (pyproject.toml) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13783 sha256=9de52a8622718f85a23e420e92df293c6c0354d2290340cc36e1157ca5bdd724
#   Stored in directory: /Users/slutch/Library/Caches/pip/wheels/0b/1d/03/175286677fb5a1341cc3e4755bf8ec0ed08f3329afd67446b0
# Successfully built docopt
# Installing collected packages: para, jsonable, docopt, propcache, mwtypes, multidict, more-itertools, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, mwapi, mwxml, mwcli, mwviews
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [mwviews]1/16 [aiohttp]
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 docopt-0.6.2 frozenlist-1.8.0 jsonable-0.3.1 more-itertools-11.1.0 multidict-6.9.0 mwapi-0.6.1 mwcli-0.0.3 mwtypes-0.4.0 mwviews-0.2.1 mwxml-0.3.8 para-0.0.8 propcache-0.5.4 yarl-1.25.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now let's use this library to request pageviews:

# %%
from mwviews.api import PageviewsClient

p = PageviewsClient(user_agent="CS315 Student learning about Wikipedia")

data = p.article_views('en.wikipedia', 
                       ['Wellesley College', 'Hillary Clinton'], # we can ask for multiple pages at once
                       start='20260101', end='20260131')

# %% [markdown]
# We should check first what kind of values are stored in the `data` variable:

# %%
type(data)
# Out:
# collections.defaultdict

# %% [markdown]
# It's a dictionary, so we can look up its items:

# %%
list(data.items())[:3]
# Out:
# [(datetime.datetime(2026, 1, 1, 0, 0),
#   {'Wellesley_College': 606, 'Hillary_Clinton': 4995}),
#  (datetime.datetime(2026, 1, 2, 0, 0),
#   {'Wellesley_College': 720, 'Hillary_Clinton': 5191}),
#  (datetime.datetime(2026, 1, 3, 0, 0),
#   {'Wellesley_College': 588, 'Hillary_Clinton': 5850})]

# %% [markdown]
# Now, let's try to look up some Kdramas from 2024, first let's make sure they have Wikipedia pages:

# %%
kdramas = ["Queen of Tears", "Lovely Runner", "Welcome to Samdal-ri"]

for k in kdramas:
    p = site.pages[k]
    print(p)
# Out:
# <Page object 'Queen of Tears' for <Site object 'en.wikipedia.org/w/'>>
# <Page object 'Lovely Runner' for <Site object 'en.wikipedia.org/w/'>>
# <Page object 'Welcome to Samdal-ri' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# Initializing and calling the pageview client:

# %%
p = PageviewsClient(user_agent="Kdrama Lover (wendy_wellesley@gmail.com)")
data = p.article_views('en.wikipedia', kdramas, 
                       start='20260801', end='20260831')

list(data.items())[:5]
# Out:
# [(datetime.datetime(2026, 8, 1, 0, 0),
#   {'Queen_of_Tears': 1000, 'Lovely_Runner': 932, 'Welcome_to_Samdal-ri': 519}),
#  (datetime.datetime(2026, 8, 2, 0, 0),
#   {'Queen_of_Tears': 1064, 'Lovely_Runner': 908, 'Welcome_to_Samdal-ri': 565}),
#  (datetime.datetime(2026, 8, 3, 0, 0),
#   {'Queen_of_Tears': 978, 'Lovely_Runner': 996, 'Welcome_to_Samdal-ri': 434}),
#  (datetime.datetime(2026, 8, 4, 0, 0),
#   {'Queen_of_Tears': 997, 'Lovely_Runner': 922, 'Welcome_to_Samdal-ri': 469}),
#  (datetime.datetime(2026, 8, 5, 0, 0),
#   {'Queen_of_Tears': 1002, 'Lovely_Runner': 882, 'Welcome_to_Samdal-ri': 485})]

# %% [markdown]
# **Your Turn:** Get the views of these Chinese Dramas:

# %%
cdramas = ['Pursuit of Jade', "Hidden Love", "When I Fly Towards You"]

for c in cdramas:
    p = site.pages[c]
    print(p)
# Out:
# <Page object 'Pursuit of Jade' for <Site object 'en.wikipedia.org/w/'>>
# <Page object 'Hidden Love' for <Site object 'en.wikipedia.org/w/'>>
# <Page object 'When I Fly Towards You' for <Site object 'en.wikipedia.org/w/'>>

# %% [markdown]
# ### Saving results into a CSV
#
# Let's see if we ask for the pageviews of a single drama for the entire lifetime of the drama. There are two ways to approach the issue of what is the "lifetime of the drama".
#
# 1. The day in which the Wiki page about the drama was created?
# 2. The day in which the drama started being broadcasted / streamed?
#
# We can get the day of the Wiki page through the revision history, or we can get the release of a drama on their MyDramaList.

# %% [markdown]
# **Note**
#
# For the purposes of saving a single file, I looked up the Wikipedia History to find the first edit on the page and this is how I got the data for Queen of Tears and Crash Landing on You. However, if we want to do this for hundreds of pages, we should use an automated process.

# %%
import datetime
import pandas as pd


def export_dict_to_csv(data):
    try:
        # Grab the first key from the first non-empty inner dictionary
        title_key = next(k for inner in data.values() for k in inner)
    except StopIteration:
        print("Dictionary or inner data is empty.")
        return

    # Extract rows and save
    rows = [
        {"date": dt.strftime("%Y-%m-%d"), "count": inner.get(title_key)}
        for dt, inner in data.items()
    ]

    filename = f"{title_key}.csv"
    pd.DataFrame(rows).to_csv(filename, index=False)
    print(f"Saved to {filename}")

# %% [markdown]
# Save the data for Crash Landing on You:

# %%
data = p.article_views('en.wikipedia', "Crash Landing on You", 
                       start='20190701', end='20260918')

export_dict_to_csv(data)
# Out:
# Saved to Crash_Landing_on_You.csv

# %% [markdown]
# Save the data for Queen of Tears:

# %% [markdown]
# data = p.article_views('en.wikipedia', "Queen of Tears",
#                        start='20220401', end='20260918')
#
# export_dict_to_csv(data)
